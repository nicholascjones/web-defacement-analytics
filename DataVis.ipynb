# %%
# Import useful libraries.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn as sk
from sklearn import preprocessing 
from sklearn.preprocessing import Imputer

data = pd.read_csv('tester.csv')

data.head()

#plt.figure();

data['R'].fillna('not R', inplace=True)
data['M'].fillna('not M', inplace=True)
data['H'].fillna('not H', inplace=True)
for col in data.columns:
    if data[col].dtype == 'object' and col != 'Class':
        plt.figure()
        #print(pd.value_counts(data[col]))
        pd.value_counts(data[col]).plot(kind="bar", title=col)
#plt.figure()
#pd.value_counts(data["Time"]).plot(kind="bar")
plt.show()
#print(len(data))
#print(data)
#data.hist()
